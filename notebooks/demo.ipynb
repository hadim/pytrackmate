# %%
import matplotlib.pyplot as plt

from pytrackmate import trackmate_peak_import

fname = "./FakeTracks.xml"
spots = trackmate_peak_import(fname)
spots.head()
# Out:
#     t_stamp    t          x         y    z    w         q  spot_id  \
# 0       0.0  0.0  28.812913  5.666830  0.0  2.0  7.669281     35.0
# 7       0.0  0.0  19.267282  5.783639  0.0  2.0  8.055871     10.0
# 16      1.0  1.0  16.392657  8.430758  0.0  2.0  9.148380     45.0
# 17      1.0  1.0  29.597818  9.571752  0.0  2.0  8.737331     46.0
# 22      2.0  2.0  15.509982  9.561214  0.0  2.0  9.911557     56.0
#
#     mean_intensity  median_intensity  min_intensity  max_intensity  \
# 0        50.226804              28.0            0.0          248.0
# 7        51.226804              30.0            2.0          239.0
# 16       49.350515              26.0            0.0          252.0
# 17       49.432990              30.0            0.0          236.0
# 22       53.649485              32.0            0.0          244.0
#
#     total_intensity  std_intensity  contrast       snr  label
# 0            4872.0      58.929072  0.235060  0.324434      0
# 7            4969.0      59.273818  0.263999  0.361010      1
# 16           4787.0      60.875221  0.444437  0.498876      2
# 17           4795.0      57.589226  0.438047  0.522942      3
# 22           5204.0      62.498007  0.471800  0.550350      4

# %%
plt.scatter(spots["x"], spots["y"], s=spots["w"] * 50)
